# %% [markdown]
# <a href="https://colab.research.google.com/github/OlivierDataS/github_actions/blob/master/Projet_Sql(060323).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation de l'environnement - la première fois seulement !

# %%
# For Python
# pip install pandas

# ORM for databases
# pip install sqlalchemy

#Python SQL Toolkit - SqlAlchemy installation
# pip install ipython-sql

# Visualisation GPS - via Conda
# !pip install matplotlib
# Geopandas et dépendances
# !pip install geopandas
# !pip install --upgrade pyshp
# !pip install --upgrade shapely
# !pip install --upgrade descartes

#pip install folium

# %% [markdown]
# Activation de SqlMagic :

# %%
# %load_ext sql
#%reload_ext sql
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# %config SqlMagic.displaylimit = 50
# %config SqlMagic.autocommit=True
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: Config option `displaycon` not recognized by `SqlMagic`.  Did you mean `displaylimit`?
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Connection/creation à la BD/schema :

# %%
# %sql sqlite:///Itineraires.db
# Out:
# 'Connected: @Itineraires.db'

# %% [markdown]
# Load tools for Python :

# %%
import pandas as pd

import geopandas as gpd
import matplotlib.pyplot as plt

import folium
from folium.plugins import MarkerCluster

from google.colab import files
from google.colab import drive
import io
#from sqlalchemy import create_engine, ForeignKey
#from sqlalchemy import Column, Date, Integer, String
#from sqlalchemy.ext.declarative import declarative_base
import sqlite3
conn = sqlite3.connect('Itineraires.db')
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# =================================== Chargement des données des référentiels

# %% [markdown]
# Création de la table référentielle des villes :

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS city_repository (
# city_id INTEGER PRIMARY KEY AUTOINCREMENT,
# nom_commune VARCHAR,
# code_postal INTEGER NOT NULL,
# Lieu_dit VARCHAR,
# gps_latitude FLOAT,
# gps_longitude FLOAT,
# Date_maj TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * sqlite:///Itineraires.db
# []

# %% [markdown]
# Création de la table référentielle des catégories par hierarchies :

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS activity_hierarchy (
# activity_id INTEGER NOT NULL,
# activity_name VARCHAR,
# activity_to INTEGER,
# Date_maj TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * sqlite:///Itineraires.db
# []

# %% [markdown]
# Création de la table référentielle des catégories médians par POI :

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS poi_activity (
# URI_ID_du_POI VARCHAR NOT NULL,
# category_sup VARCHAR,
# category_inf VARCHAR,
# Categories_de_poi VARCHAR,
# Date_maj TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * sqlite:///Itineraires.db
# []

# %% [markdown]
# Import des données "city" par l'intermédiaire d'un fichier puis d'un dataframe (correspondance des noms de colonnes) :

# %%
import_city_repository = pd.read_csv('/content/drive/MyDrive/CSV4DB/SQL_city_repository.csv')

# %%
import_city_repository.to_sql('city_repository', conn, if_exists='append', index=False)

# %% [markdown]
# Vérifications :

# %%
import_city_repository.count()
# Out:
# nom_commune      85
# code_postal      85
# Lieu_dit         61
# gps_latitude     85
# gps_longitude    85
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM city_repository
# Out:
#  * sqlite:///Itineraires.db
# [(85,)]

# %%
# %%sql
# SELECT * FROM city_repository
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [(1, 'ST DENIS', 97490, 'BOIS DE NEFLES ST DENIS', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (2, 'ST DENIS', 97490, 'ST DENIS CHAUDRON', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (3, 'ST DENIS', 97490, 'LA BRETAGNE', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (4, 'ST DENIS', 97490, 'MOUFIA', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (5, 'ST DENIS', 97490, 'STE CLOTILDE', -20.933029099, 55.446977555, '2023-03-06 10:03:25')]

# %% [markdown]
# Import des données "activity" :

# %%
import_activity_hierarchy = pd.read_csv('/content/drive/MyDrive/CSV4DB/SQL_activity_hierarchy.csv')

# %%
import_activity_hierarchy.to_sql('activity_hierarchy', conn, if_exists='append', index=False)

# %% [markdown]
# Vérifications :

# %%
import_activity_hierarchy.count()
# Out:
# activity_id      252
# activity_name    252
# activity_to      251
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM activity_hierarchy
# Out:
#  * sqlite:///Itineraires.db
# [(252,)]

# %%
# %%sql
# SELECT * FROM activity_hierarchy
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [(1, 'PointOfInterest', None),
#  (2, 'PlaceOfInterest', 1.0),
#  (3, 'ActivityProvider', 2.0),
#  (4, 'CulturalSite', 2.0),
#  (5, 'FoodEstablishment', 2.0)]

# %% [markdown]
# Import des données "category median" :

# %%
import_poi_activity = pd.read_csv('/content/drive/MyDrive/CSV4DB/SQL_poi_activity.csv')

# %%
import_poi_activity.to_sql('poi_activity', conn, if_exists='append', index=False)

# %% [markdown]
# Vérifications :

# %%
import_poi_activity.count()
# Out:
# URI_ID_POI           3571
# category_sup         3571
# category_median      3571
# categories_de_POI    3571
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM poi_activity
# Out:
#  * sqlite:///Itineraires.db
# [(7142,)]

# %%
# %%sql
# SELECT * FROM poi_activity
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [('27441221-b465-3609-9cf6-203aec7a8bc9', 'Accommodation', 'LodgingBusiness', 'Accommodation|RentalAccommodation|Accommodation|LodgingBusiness', '2023-03-06 10:32:20'),
#  ('ce516e2d-f9f2-332b-bdd0-ce47545cef43', 'Accommodation', 'LodgingBusiness', 'Accommodation|RentalAccommodation|Accommodation|LodgingBusiness', '2023-03-06 10:32:20'),
#  ('3125c269-e57c-3e19-9b87-253c37dba398', 'Accommodation', 'LodgingBusiness', 'Accommodation|RentalAccommodation|Accommodation|LodgingBusiness', '2023-03-06 10:32:20'),
#  ('318cd437-537a-3d65-83bc-2f9c3ff9452a', 'Accommodation', 'LodgingBusiness', 'Accommodation|RentalAccommodation|Accommodation|LodgingBusiness', '2023-03-06 10:32:20'),
#  ('32e09e05-74be-3dc5-8b3b-317c8d2dc723', 'Accommodation', 'LodgingBusiness', 'Accommodation|RentalAccommodation|Accommodation|LodgingBusiness', '2023-03-06 10:32:20')]

# %% [markdown]
# ===================================
# Chargement des données POI - les tables sont crées depuis leurs dataframes.

# %% [markdown]
# Dataframe/table du fichier reunion_clean.csv :

# %%
poi_reunion_clean = pd.read_csv('/content/drive/MyDrive/CSV4DB/reunion_clean.csv')

# %%
# %sql persist poi_reunion_clean
# Out:
#  * sqlite:///Itineraires.db
# 'Persisted poi_reunion_clean'

# %% [markdown]
# Vérifications :

# %%
poi_reunion_clean.count()
# Out:
# ID                     1959
# Nom_du_POI             1959
# Latitude               1959
# Longitude              1959
# Adresse_postale        1865
# Date_de_mise_a_jour    1959
# Contacts_du_POI        1865
# Description              29
# region                 1959
# commune                1959
# code_postal            1959
# subclass_0             1959
# subclass_1               71
# superclass_0           1959
# superclass_1             71
# dtype: int64

# %%
# %%sql
# SELECT count(*) FROM poi_reunion_clean;
# Out:
#  * sqlite:///Itineraires.db
# [(1959,)]

# %%
# %%sql
# SELECT * FROM poi_reunion_clean
# LIMIT 5;
# Out:
#  * sqlite:///Itineraires.db
# [(0, '187a27ff-8ad2-3298-9b2f-064023dd042b', 'Lentille des Gourmets (La)', -21.13588418, 55.479501, '40 E, chemin des Trois Mares', '2022-05-30', 'Lentille des Gourmets (La)#+33 2 62 31 85 85#hotel@lecilaos.re#http://leschenets-lecilaos.re/', None, 54, 'Cilaos', 97413, 'Restaurant', None, 'FoodEstablishment', None),
#  (1, 'ac5515a8-d78e-35ed-a51e-6fc6b1ddbb2b', 'Neptune (Le)', -21.34144, 55.462664, '117, boulevard Hubert Delisle', '2021-07-13', 'Neptune (Le)#+33 2 62 61 61 61#reservation@lebattantdeslames.com#http://www.lebattantdeslames.com/', None, 54, 'Saint-Pierre', 97410, 'LeisureSportActivityProvider', None, 'ActivityProvider', None),
#  (2, '43079596-c868-3cfe-a280-aeaf15d5666c', 'Grand Large (Le)', -21.34144, 55.462664, '117, boulevard Hubert Delisle', '2021-07-13', 'Grand Large (Le)#+33 2 62 61 61 61#reservation@lebattantdeslames.com#http://www.lebattantdeslames.com/', None, 54, 'Saint-Pierre', 97410, 'Restaurant', None, 'FoodEstablishment', None),
#  (3, 'f2a140d5-152c-300b-accb-67619012a89a', 'Concorde (Le)', -20.89625806, 55.44723605, '91 bis, allée des Topazes - Bellepierre', '2019-10-10', 'Concorde (Le)#+33 2 62 51 51 51#info@hotel-bellepierre.com#http://www.hotel-bellepierre.com/', None, 54, 'Saint-Denis', 97400, 'Restaurant', 'LeisureSportActivityProvider', 'FoodEstablishment', 'ActivityProvider'),
#  (4, '9c77eb5d-8fd9-3700-8e77-e830870e9669', "Jardin de la Maison d'Edith (Le)", -20.889919, 55.407147, '59, chemin Commins', '2020-05-07', "Jardin de la Maison d'Edith (Le)#+33 6 92 69 66 05#maisondedith@gmail.com#http://www.maisondedith.com/", None, 54, 'Saint-Denis', 97417, 'CulturalSite', None, 'CulturalSite', None)]

# %% [markdown]
# Dataframe/table du fichier reunion_activity.csv :

# %%
poi_reunion_activity = pd.read_csv('/content/drive/MyDrive/CSV4DB/reunion_activity.csv')

# %%
# %sql persist poi_reunion_activity
# Out:
#  * sqlite:///Itineraires.db
# 'Persisted poi_reunion_activity'

# %% [markdown]
# Vérifications :

# %%
poi_reunion_activity.count()
# Out:
# ID                     241
# Nom_du_POI             241
# Latitude               241
# Longitude              241
# Adresse_postale        233
# Date_de_mise_a_jour    241
# Contacts_du_POI        233
# Description              1
# region                 241
# commune                241
# code_postal            241
# category_0             241
# category_1             241
# category_2               2
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM poi_reunion_activity
# Out:
#  * sqlite:///Itineraires.db
# [(241,)]

# %% [markdown]
# Dataframe/table du fichier reunion_food.csv :

# %%
poi_reunion_food = pd.read_csv('/content/drive/MyDrive/CSV4DB/reunion_food.csv')

# %%
# %sql persist poi_reunion_food
# Out:
#  * sqlite:///Itineraires.db
# 'Persisted poi_reunion_food'

# %%
Vérifications :

# %%
poi_reunion_food.count()
# Out:
# ID                     1195
# Nom_du_POI             1195
# Latitude               1195
# Longitude              1195
# Adresse_postale        1195
# Date_de_mise_a_jour    1195
# Contacts_du_POI        1195
# Description               0
# region                 1195
# commune                1195
# code_postal            1195
# category_0             1195
# category_1              878
# category_2               55
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM poi_reunion_food
# Out:
#  * sqlite:///Itineraires.db
# [(1195,)]

# %% [markdown]
# Dataframe/table du fichier ontology_hierarchy_descending_SQL.csv (modifié):

# %%
poi_reunion_2 = pd.read_csv('/content/drive/MyDrive/CSV4DB/reunion_poi_2.csv')

# %%
# %sql persist poi_reunion_2
# Out:
#  * sqlite:///Itineraires.db
# 'Persisted poi_reunion_2'

# %% [markdown]
# Vérifications :

# %%
poi_reunion_2.count()
# Out:
# ID                     314
# Nom_du_POI             314
# Latitude               314
# Longitude              314
# Adresse_postale        227
# Date_de_mise_a_jour    314
# Contacts_du_POI        227
# Description             28
# region                 314
# commune                314
# code_postal            314
# category_0             307
# category_1             105
# category_2              21
# dtype: int64

# %%
# %%sql
# SELECT COUNT(*) FROM poi_reunion_2
# Out:
#  * sqlite:///Itineraires.db
# [(314,)]

# %% [markdown]
# Dataframe/table du fichier reunion_poi_2.csv (modifié):

# %%
ontology_hierarchy_descending = pd.read_csv('/content/drive/MyDrive/CSV4DB/ontology_hierarchy_descending_SQL.csv')

# %%
# %sql persist ontology_hierarchy_descending

# %% [markdown]
# Vérifications :

# %%
ontology_hierarchy_descending.count()
# Out:
# PointOfInterest    231
# PlaceOfInterest    231
# activity0          231
# activity1          231
# activity2           62
# dtype: int64

# %%
# %%sql
# SELECT count(*) FROM ontology_hierarchy_descending;
# Out:
#  * sqlite:///Itineraires.db
# [(231,)]

# %% [markdown]
# Dataframe/table du fichier subclass_class_relations.csv :

# %%
activity_subclass_class_relations = pd.read_csv('/content/drive/MyDrive/CSV4DB/subclass_class_relations.csv')

# %%
# %sql persist activity_subclass_class_relations
# Out:
#  * sqlite:///Itineraires.db
# 'Persisted activity_subclass_class_relations'

# %% [markdown]
# Vérifications :

# %%
activity_subclass_class_relations.count()
# Out:
# subclass    250
# class       250
# dtype: int64

# %%
# %%sql
# SELECT count(*) FROM activity_subclass_class_relations;
# Out:
#  * sqlite:///Itineraires.db
# [(250,)]

# %% [markdown]
# ========================================================================
# Présence des tables :
#
# *   city_repository
# *   activity_hierarchy
# *   poi_activity
# *   poi_reunion_clean
# *   poi_reunion_activity
# *   poi_reunion_food
# *   poi_reunion_2
# *   ontology_hierarchy_descending
# *   activity_subclass_class_relations
#
#
#
# Exemples de requêtes :

# %%
# %%sql
# SELECT nom_commune, COUNT(Lieu_dit), gps_latitude, gps_longitude
# FROM city_repository
# GROUP BY nom_commune
# ORDER BY 2 DESC
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [('ST DENIS', 12, -20.933029099, 55.446977555),
#  ('ST PAUL', 10, -21.044520611, 55.322330771),
#  ('ST PIERRE', 6, -21.312265663, 55.49381116),
#  ('LE TAMPON', 5, -21.223167157, 55.558552873),
#  ('STE MARIE', 3, -20.946751887, 55.530655328)]

# %%
# %%sql
# SELECT * FROM ontology_hierarchy_descending
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [(0, 'PointOfInterest', 'PlaceOfInterest', 'ActivityProvider', 'CulturalActivityProvider', None),
#  (1, 'PointOfInterest', 'PlaceOfInterest', 'ActivityProvider', 'LeisureSportActivityProvider', None),
#  (2, 'PointOfInterest', 'PlaceOfInterest', 'CulturalSite', 'ArcheologicalSite', 'MegalithDolmenMenhir'),
#  (3, 'PointOfInterest', 'PlaceOfInterest', 'CulturalSite', 'ArcheologicalSite', 'RomanPath'),
#  (4, 'PointOfInterest', 'PlaceOfInterest', 'CulturalSite', 'ArcheologicalSite', 'Ruins')]

# %%
# %%sql
# SELECT class, subclass
# FROM activity_subclass_class_relations
# LIMIT 5
# Out:
#  * sqlite:///Itineraires.db
# [('ReligiousSite', 'Abbey'),
#  ('PlaceOfInterest', 'ActivityProvider'),
#  ('Transport', 'Airfield'),
#  ('Transport', 'Airport'),
#  ('NaturalHeritage', 'AlpinePasture')]

# %%
# %%sql
# SELECT activity_name
# FROM activity_hierarchy
# WHERE activity_to =
# (SELECT activity_id
# FROM activity_hierarchy
# WHERE activity_name = 'CulturalSite')
# Out:
#  * sqlite:///Itineraires.db
# [('ArcheologicalSite',),
#  ('CityHeritage',),
#  ('DefenceSite',),
#  ('InterpretationCentre',),
#  ('Library',),
#  ('Museum',),
#  ('ParkAndGarden',),
#  ('ReligiousSite',),
#  ('RemarkableBuilding',),
#  ('RemembranceSite',),
#  ('TechnicalHeritage',)]

# %%
# %%sql
# SELECT subclass_0, COUNT(subclass_0)
# FROM poi_reunion_clean
# WHERE superclass_0 = 'CulturalSite'
# GROUP BY subclass_0;
# Out:
#  * sqlite:///Itineraires.db
# [('Bridge', 1),
#  ('Church', 5),
#  ('CulturalSite', 85),
#  ('Mosque', 1),
#  ('TechnicalHeritage', 34),
#  ('Temple', 3)]

# %%
# %%sql
# SELECT category_median, COUNT(category_median)
# FROM poi_activity
# WHERE category_sup = 'CulturalSite'
# GROUP BY category_median;
# Out:
#  * sqlite:///Itineraires.db
# [('CulturalSite', 170),
#  ('ReligiousSite', 18),
#  ('RemarkableBuilding', 2),
#  ('TechnicalHeritage', 66)]

# %%
# Résultat de la requête dans un DF
# activity_CulturalSite = _
# display(activity_CulturalSite)
# %%sql
result << SELECT prc.Nom_du_POI, prc.commune, prc.code_postal, prc.Latitude, prc.Longitude, pa.category_median
FROM poi_reunion_clean prc, poi_activity pa
WHERE ID = URI_ID_POI
AND category_median IN
(
  SELECT activity_name 
FROM activity_hierarchy
WHERE activity_to =
(SELECT activity_id 
FROM activity_hierarchy
WHERE activity_name = 'CulturalSite')
)
ORDER BY 3;
# Out:
#  * sqlite:///Itineraires.db
# Returning data to local variable result

# %%
print(result)
# Out:
# +-----------------------------------------------------------------+-------------------------+-------------+--------------+-------------+-------------------+
# |                            Nom_du_POI                           |         commune         | code_postal |   Latitude   |  Longitude  |  category_median  |
# +-----------------------------------------------------------------+-------------------------+-------------+--------------+-------------+-------------------+
# |                        Temple Kali Kampal                       |       Saint-Denis       |    97400    |  -20.880661  |  55.458077  |   ReligiousSite   |
# |                      Cathédrale Saint-Denis                     |       Saint-Denis       |    97400    |  -20.877163  |  55.448789  |   ReligiousSite   |
# |                       Mosquée Noor-e-Islam                      |       Saint-Denis       |    97400    |  -20.879185  |  55.452474  |   ReligiousSite   |
# |                        Temple Kali Kampal                       |       Saint-Denis       |    97400    |  -20.880661  |  55.458077  |   ReligiousSite   |
# |                      Cathédrale Saint-Denis                     |       Saint-Denis       |    97400    |  -20.877163  |  55.448789  |   ReligiousSite   |
# |                       Mosquée Noor-e-Islam                      |       Saint-Denis       |    97400    |  -20.879185  |  55.452474  |   ReligiousSite   |
# |                        Saga du Rhum (La)                        |       Saint-Pierre      |    97410    |  -21.312109  |  55.465557  | TechnicalHeritage |
# |                     Rhums et Punchs Isautier                    |       Saint-Pierre      |    97410    |  -21.320276  |  55.474025  | TechnicalHeritage |
# |                     Charrette de Baster (La)                    |       Saint-Pierre      |    97410    |  -21.325298  |  55.484798  | TechnicalHeritage |
# |                        Saga du Rhum (La)                        |       Saint-Pierre      |    97410    |  -21.312109  |  55.465557  | TechnicalHeritage |
# |                     Rhums et Punchs Isautier                    |       Saint-Pierre      |    97410    |  -21.320276  |  55.474025  | TechnicalHeritage |
# |                     Charrette de Baster (La)                    |       Saint-Pierre      |    97410    |  -21.325298  |  55.484798  | TechnicalHeritage |
# |                   Coopérative Provanille (La)                   |        Bras-Panon       |    97412    |  -21.000724  |  55.687307  | TechnicalHeritage |
# |                   Coopérative Provanille (La)                   |        Bras-Panon       |    97412    |  -21.000724  |  55.687307  | TechnicalHeritage |
# |                       Chai de Cilaos (Le)                       |          Cilaos         |    97413    |  -21.134936  |   55.47241  | TechnicalHeritage |
# |                       Chai de Cilaos (Le)                       |          Cilaos         |    97413    |  -21.134936  |   55.47241  | TechnicalHeritage |
# |                              Edena                              |      La Possession      |    97419    |  -20.962967  |  55.321357  | TechnicalHeritage |
# |                              Edena                              |      La Possession      |    97419    |  -20.962967  |  55.321357  | TechnicalHeritage |
# |                         Atelier Mascarin                        |         Le Port         |    97420    |  -20.949323  |  55.288668  | TechnicalHeritage |
# |                      Galvanisation Réunion                      |         Le Port         |    97420    |  -20.931438  |  55.290552  | TechnicalHeritage |
# |                         Atelier Mascarin                        |         Le Port         |    97420    |  -20.949323  |  55.288668  | TechnicalHeritage |
# |                      Galvanisation Réunion                      |         Le Port         |    97420    |  -20.931438  |  55.290552  | TechnicalHeritage |
# |                 Part des Anges Distillation (La)                |        Saint-Paul       |    97422    |  -21.07987   |  55.272865  | TechnicalHeritage |
# |                 Part des Anges Distillation (La)                |        Saint-Paul       |    97422    |  -21.07987   |  55.272865  | TechnicalHeritage |
# |                     Maison du Géranium (La)                     |        Saint-Paul       |    97423    |  -21.050558  |  55.352149  | TechnicalHeritage |
# |                     Maison du Géranium (La)                     |        Saint-Paul       |    97423    |  -21.050558  |  55.352149  | TechnicalHeritage |
# |                    Ferme du Piton Rouge (La)                    |       Les Avirons       |    97425    |  -21.238314  |  55.342359  | TechnicalHeritage |
# |                    Ferme du Piton Rouge (La)                    |       Les Avirons       |    97425    |  -21.238314  |  55.342359  | TechnicalHeritage |
# |                            Crête D'or                           |       L'Étang-Salé      |    97427    |  -21.277105  |  55.373238  | TechnicalHeritage |
# |                            Crête D'or                           |       L'Étang-Salé      |    97427    |  -21.277105  |  55.373238  | TechnicalHeritage |
# |                     Maison de l'Abeille (La)                    |        Petite-Île       |    97429    | -21.35991853 | 55.56013895 | TechnicalHeritage |
# |                       Ferme Auberge Dy-Na                       |        Petite-Île       |    97429    |  -21.339637  |  55.587062  | TechnicalHeritage |
# |                     Maison de l'Abeille (La)                    |        Petite-Île       |    97429    | -21.35991853 | 55.56013895 | TechnicalHeritage |
# |                       Ferme Auberge Dy-Na                       |        Petite-Île       |    97429    |  -21.339637  |  55.587062  | TechnicalHeritage |
# | Coopérative Agricole des Huiles Essentielles de Bourbon - CAHEB |        Le Tampon        |    97430    |  -21.287056  |  55.520454  | TechnicalHeritage |
# | Coopérative Agricole des Huiles Essentielles de Bourbon - CAHEB |        Le Tampon        |    97430    |  -21.287056  |  55.520454  | TechnicalHeritage |
# |     Au Coeur de la Cascade Biberon - Cueillette de Goyaviers    | La Plaine-des-Palmistes |    97431    |  -21.126268  |  55.627094  | TechnicalHeritage |
# |             Verger Delatre - Cueillette de Goyavier             | La Plaine-des-Palmistes |    97431    | -21.13170728 | 55.61492483 | TechnicalHeritage |
# |     Au Coeur de la Cascade Biberon - Cueillette de Goyaviers    | La Plaine-des-Palmistes |    97431    |  -21.126268  |  55.627094  | TechnicalHeritage |
# |             Verger Delatre - Cueillette de Goyavier             | La Plaine-des-Palmistes |    97431    | -21.13170728 | 55.61492483 | TechnicalHeritage |
# |   Place de la Mairie et de l'Eglise Notre Dame de l'Assomption  |         Salazie         |    97433    |  -21.028035  |  55.539164  |   ReligiousSite   |
# |   Place de la Mairie et de l'Eglise Notre Dame de l'Assomption  |         Salazie         |    97433    |  -21.028035  |  55.539164  |   ReligiousSite   |
# |                         Chapelle Pointue                        |        Saint-Paul       |    97435    |  -21.055922  |   55.26375  |   ReligiousSite   |
# |                         Chapelle Pointue                        |        Saint-Paul       |    97435    |  -21.055922  |   55.26375  |   ReligiousSite   |
# |                     Fontaine Aromatique (La)                    |        Saint-Leu        |    97436    |  -21.157974  |  55.297404  | TechnicalHeritage |
# |                     Fontaine Aromatique (La)                    |        Saint-Leu        |    97436    |  -21.157974  |  55.297404  | TechnicalHeritage |
# |                             AVPPHSM                             |       Saint-Benoît      |    97437    |  -21.094911  |  55.696433  | TechnicalHeritage |
# |                      Eglise de Sainte-Anne                      |       Saint-Benoît      |    97437    |  -21.08012   |  55.742847  |   ReligiousSite   |
# |                       Domaine de Coco (Le)                      |       Saint-Benoît      |    97437    |  -21.081206  |  55.719019  | TechnicalHeritage |
# |                             AVPPHSM                             |       Saint-Benoît      |    97437    |  -21.094911  |  55.696433  | TechnicalHeritage |
# +-----------------------------------------------------------------+-------------------------+-------------+--------------+-------------+-------------------+

# %%
result.csv('/content/drive/MyDrive/CSV4DB/result.csv')
# Out:
# CSV results at /content/drive/MyDrive/CSV4DB/result.csv

# %%
result = pd.read_csv('/content/drive/MyDrive/CSV4DB/result.csv')
result.head()
# Out:
#                Nom_du_POI      commune  code_postal   Latitude  Longitude  \
# 0      Temple Kali Kampal  Saint-Denis        97400 -20.880661  55.458077
# 1  Cathédrale Saint-Denis  Saint-Denis        97400 -20.877163  55.448789
# 2    Mosquée Noor-e-Islam  Saint-Denis        97400 -20.879185  55.452474
# 3      Temple Kali Kampal  Saint-Denis        97400 -20.880661  55.458077
# 4  Cathédrale Saint-Denis  Saint-Denis        97400 -20.877163  55.448789
#
#   category_median
# 0   ReligiousSite
# 1   ReligiousSite
# 2   ReligiousSite
# 3   ReligiousSite
# 4   ReligiousSite

# %%
# Conversion des coordonnées géographiques
gdf = gpd.GeoDataFrame(
    result, geometry=gpd.points_from_xy(result.Longitude, result.Latitude))
gdf.head()
# Out:
#                Nom_du_POI      commune  code_postal   Latitude  Longitude  \
# 0      Temple Kali Kampal  Saint-Denis        97400 -20.880661  55.458077
# 1  Cathédrale Saint-Denis  Saint-Denis        97400 -20.877163  55.448789
# 2    Mosquée Noor-e-Islam  Saint-Denis        97400 -20.879185  55.452474
# 3      Temple Kali Kampal  Saint-Denis        97400 -20.880661  55.458077
# 4  Cathédrale Saint-Denis  Saint-Denis        97400 -20.877163  55.448789
#
#   category_median                    geometry
# 0   ReligiousSite  POINT (55.45808 -20.88066)
# 1   ReligiousSite  POINT (55.44879 -20.87716)
# 2   ReligiousSite  POINT (55.45247 -20.87918)
# 3   ReligiousSite  POINT (55.45808 -20.88066)
# 4   ReligiousSite  POINT (55.44879 -20.87716)

# %%
# Polygones des départements français
import zipfile
import requests

# A partir de l'url :
url_dep = "http://osm13.openstreetmap.fr/~cquest/openfla/export/departements-20180101-shp.zip"

file_dep = "departements-20180101-shp.zip"

r = requests.get(url_dep)

open(file_dep, 'wb').write(r.content)

with zipfile.ZipFile(file_dep, 'r') as unzip: unzip.extractall("dep.shp")

dep = gpd.read_file("dep.shp")

# dep.head()

# %%
# Visualisation de la localisation
fig, ax = plt.subplots(figsize = (10,10))
dep[dep.code_insee == '974'].plot(ax=ax,color='white', edgecolor='black')
gdf.plot(ax=ax,column="category_median", s=150, legend=True)
ax.set_title('Ile de La Réunion')
# Out:
# Text(0.5, 1.0, 'Ile de La Réunion')

# %%
# Via FOLIUM - première approche

map = folium.Map(location=[result.Latitude.mean(), result.Longitude.mean()], 
                 zoom_start=11, 
                 control_scale=True)


purpose_colour = {'RemarkableBuilding':'red', 'ReligiousSite':'green', 'TechnicalHeritage':'blue'}

#Loop through each row in the dataframe
for i,row in result.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame(f'Nom: {str(row.Nom_du_POI)} \n Categorie: {str(row.category_1)}')
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=200, max_width=150)
    

    try:
        icon_color = purpose_colour[row.category_1]
    except:
        icon_color = 'gray'
    
    #Add each row to the map
    folium.Marker(location=[row.Latitude,row.Longitude],
                  popup = popup, 
                  icon=folium.Icon(color=icon_color, icon='')).add_to(map)


folium.TileLayer('openstreetmap').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)
folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_727d5ed162605ae867e875b921f20e2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_727d5ed162605ae867e875b921f20e2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_727d5ed162605ae867e875b921f20e2e = L.map(
#                 &quot;map_727d5ed162605ae867e875b921f20e2e&quot;,
#                 {
#                     center: [-21.127057736511627, 55.54462842488372],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_727d5ed162605ae867e875b921f20e2e);
#
#
#
#
#
#             var tile_layer_796b89bad7f00866622a04f62080a6ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_727d5ed162605ae867e875b921f20e2e);
#
#
#             var marker_8ba6e22ee02ea98ba4e9d7723ea269ab = L.marker(
#                 [-20.880661, 55.458077],
#                 {}
#             ).addTo(map_727d5ed162605ae867e875b921f20e2e);
#
#
#             var icon_587def45bf4ea2e95cba0ce9a991ef13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ba6e22ee02ea98ba4e9d7723ea269ab.setIcon(icon_587def45bf4ea2e95cba0ce9a991ef13);
#
#
#         var popup_969f3ca40665765de13decedf0f22551 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_ec8fd97f58c39d6c8e4edd6fcc4be8e5 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOb206IFRlbXBsZSBLYWxpIEthbXBhbCAKIENhdGVnb3JpZTogUmVsaWdpb3VzU2l0ZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_969f3ca40665765de13decedf0f22551.setContent(i_frame_ec8fd97f58c39d6c8e4edd6fcc4be8e5);
#
#
#         marker_8ba6e22ee02ea98ba4e9d7723ea269ab.bindPopup(popup_969f3ca40665765de13decedf0f22551)
#         ;
#
#
#
#
#             var marker_8aec82866db3f9a8bb39651436946ce3 = L.marker(
#                 [-20.877163, 55.448789],
#                 {}
#             ).addTo(map_727d5ed162605ae867e875b921f20e2e);
#
#
#             var icon_433f5fe3769c8f972f4777e0fd2cc762 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8aec82866db3f9a8bb39651436946ce3.setIcon(icon_433f5fe3769c8f972f4777e0fd2cc762);
#
#
#         var popup_6e4b73fe2d7d8af94d4320675138bdd3 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_3b6c0b3a896490f5ecef949a7a7edd38 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOb206IENhdGjDqWRyYWxlIFNhaW50LURlbmlzIAogQ2F0ZWdvcmllOiBSZWxpZ2lvdXNTaXRl&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_6e4b73fe2d7d8af94d4320675138bdd3.setContent(i_frame_3b6c0b3a896490f5ecef949a7a7edd38);
#
#
#         marker_8aec82866db3f9a8bb39651436946ce3.bindPopup(popup_6e4b73fe2d7d8af94d4320675138bdd3)
#         ;
#
#
#
#
#             var marker_0a3a1d99736710d3703459de13ffead4 = L.marker(
#                 [-20.879185, 55.452474],
#                 {}
#             ).addTo(map_727d5ed162605ae867e875b921f20e2e);
#
#
#             var icon_e36c110d53266a669855ddc3b6446f55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a3a1d99736710d3703459de13ffead4.setIcon(icon_e36c110d53266a669855ddc3b6446f55);
#
#
#         var popup_8739e9aed938baf97dba5c9879bcf4a5 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_c0fd7d4402d5778c724d75f85dd0996a = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOb206IE1vc3F1w6llIE5vb3ItZS1Jc2xhbSAKIENhdGVnb3JpZTogUmVsaWdpb3VzU2l0ZQ==&quot; style=&quot;position:absolute;width:100%;

# %%
# Via FOLIUM - approche confuse associant GROUP (cf légende) et CLUSTER (pas top pour les affichages)

category=result.groupby('category_1').count().index

map = folium.Map(location=[result.Latitude.mean(), result.Longitude.mean()], 
                 icon_size=(100,100),
                 icon_anchor=(40,2),
                 zoom_start=11, 
                 control_scale=True)

for index, cat in enumerate(category):

  exec("fg"+str(index)+"=folium.FeatureGroup(name='"+str(cat)+"', show=True)")
  exec("map.add_child(fg"+str(index)+")")
  exec("marker_cluster"+str(index)+" = MarkerCluster().add_to(fg"+str(index)+")")

  icon_color_list = ['darkpurple', 'red', 'darkblue', 'black', 'lightred', 'gray', 'lightblue', 'lightgray', 'beige', 'darkred', 'white', 'cadetblue', 'purple', 'blue', 'orange', 'pink']
  icon_color = icon_color_list[index]

  # test = result[result.category_1==cat]

  for i, row in result[result.category_1==cat].iterrows():

    iframe = folium.IFrame(f'Nom: {str(row.Nom_du_POI)} \n Categorie: {str(row.category_1)}')
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=200, max_width=150)



    exec("folium.Marker(location=[row.Latitude,row.Longitude], popup = popup, icon=folium.Icon(color=icon_color, icon='')).add_to(marker_cluster"+str(index)+")")



folium.TileLayer('openstreetmap').add_to(map)
folium.TileLayer('Stamen Terrain').add_to(map)
folium.LayerControl().add_to(map) 

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c63fa24cd8fd3721d76f7c2098dc64e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c63fa24cd8fd3721d76f7c2098dc64e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c63fa24cd8fd3721d76f7c2098dc64e7 = L.map(
#                 &quot;map_c63fa24cd8fd3721d76f7c2098dc64e7&quot;,
#                 {
#                     center: [-21.127057736511627, 55.54462842488372],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     iconSize: [100, 100],
#                     iconAnchor: [40, 2],
#                 }
#             );
#             L.control.scale().addTo(map_c63fa24cd8fd3721d76f7c2098dc64e7);
#
#
#
#
#
#             var tile_layer_34d1e593b83a3f8240e58fc581b041ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c63fa24cd8fd3721d76f7c2098dc64e7);
#
#
#             var feature_group_42687deecc2323b625c6544d7804a1e2 = L.featureGroup(
#                 {}
#             ).addTo(map_c63fa24cd8fd3721d76f7c2098dc64e7);
#
#
#             var marker_cluster_c07a58efbe5698e03840cec50bc0761d = L.markerClusterGroup(
#                 {}
#             );
#             feature_group_42687deecc2323b625c6544d7804a1e2.addLayer(marker_cluster_c07a58efbe5698e03840cec50bc0761d);
#
#
#             var marker_51186611ff7b37741062a5dfd293577b = L.marker(
#                 [-20.880661, 55.458077],
#                 {}
#             ).addTo(marker_cluster_c07a58efbe5698e03840cec50bc0761d);
#
#
#             var icon_c0868491b0cd0d88e472e112d08a308b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51186611ff7b37741062a5dfd293577b.setIcon(icon_c0868491b0cd0d88e472e112d08a308b);
#
#
#         var popup_4f4ef99b22826ec59b63fc5bf2e832fb = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_e1f92ad6320804b158d788c419f74e07 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOb206IFRlbXBsZSBLYWxpIEthbXBhbCAKIENhdGVnb3JpZTogUmVsaWdpb3VzU2l0ZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_4f4ef99b22826ec59b63fc5bf2e832fb.setContent(i_frame_e1f92ad6320804b158d788c419f74e07);
#
#
#         marker_51186611ff7b37741062a5dfd293577b.bindPopup(popup_4f4ef99b22826ec59b63fc5bf2e832fb)
#         ;
#
#
#
#
#             var marker_d04efd6264c66df8fcfc137c60f6acc2 = L.marker(
#                 [-20.877163, 55.448789],
#                 {}
#             ).addTo(marker_cluster_c07a58efbe5698e03840cec50bc0761d);
#
#
#             var icon_487ead2900a084bc31b6bb49694e50b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkpurple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d04efd6264c66df8fcfc137c60f6acc2.setIcon(icon_487ead2900a084bc31b6bb49694e50b0);
#
#
#         var popup_232b80c25ebb9297886596f97944238d = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_d63b2dd474d74686069cf302b89dbc9e = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOb206IENhdGjDqWRyYWxlIFNhaW50LURlbmlzIAogQ2F0ZWdvcmllOiBSZWxpZ2lvdXNTaXRl&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_232b80c25ebb9297886596f97944238d.setContent(i_frame_d63b2dd474d74686069cf302b89dbc9e);
#
#
#         marker_d04efd6264c66df8fcfc137c60f6acc2.bindPopup(popup_232b80c25ebb9297886596f97944238d)
#         ;
#
#
#
#
#             var marker_bcfb0867057a9c86414c05cbb6ae1937 = L.marker(
#                 [-20.879185, 55.452474],
#                 {}
#             ).addTo(marker_

# %%
# Via FOLIUM - approche GROUP (cf légende) seulement

map = folium.Map(location=[result.Latitude.mean(), result.Longitude.mean()], 
                 zoom_start=11, 
                 tiles='openstreetmap',
                 control_scale=True)

icon_symbol_list = ['', 'star', 'flag', 'male']

icon_color_list = ['green', 'red', 'blue', 'darkpurple', 'yellow', 'black', 'lightred', 'gray', 'lightblue', 'lightgray', 'lightgreen', 'beige', 'darkred', 'white', 'cadetblue', 'purple', 'darkblue', 'orange', 'pink']
icon_color_num = 0 

for cat, result_gb in result.groupby('category_median'):

  fg = folium.FeatureGroup(cat)

  icon_color = icon_color_list[icon_color_num]
  icon_color_num = icon_color_num + 1

  for row in result_gb.itertuples():
    
    iframe = folium.IFrame('*Nom: '+str(row.Nom_du_POI)+'<br>'+'*Categorie: '+str(row.category_median))
    
    popup = folium.Popup(iframe, min_width=200, max_width=200)


    folium.Marker(location=[row.Latitude, row.Longitude], popup = popup, icon=folium.Icon(color=icon_color, icon='', prefix='')).add_to(fg)
    fg.add_to(map)


folium.TileLayer('Stamen Terrain').add_to(map)
folium.TileLayer('openstreetmap').add_to(map)
folium.LayerControl(position='topright', collapsed=False).add_to(map) 

map.save('/content/drive/MyDrive/CSV4DB/reunion.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_952d558462c66c8f647e9c0bace738be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_952d558462c66c8f647e9c0bace738be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_952d558462c66c8f647e9c0bace738be = L.map(
#                 &quot;map_952d558462c66c8f647e9c0bace738be&quot;,
#                 {
#                     center: [-21.127057736511624, 55.54462842488371],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_952d558462c66c8f647e9c0bace738be);
#
#
#
#
#
#             var tile_layer_2d8f8fafd4f8fd80059b66330c0e7e33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_952d558462c66c8f647e9c0bace738be);
#
#
#             var feature_group_84b247d9dba4f7d1ff3a88435874198f = L.featureGroup(
#                 {}
#             ).addTo(map_952d558462c66c8f647e9c0bace738be);
#
#
#             var marker_40096768bfa0e497a4211a2bd2ab6bf9 = L.marker(
#                 [-20.880661, 55.458077],
#                 {}
#             ).addTo(feature_group_84b247d9dba4f7d1ff3a88435874198f);
#
#
#             var icon_4eb9d56e1d61a7704e94642fce1f995f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;&quot;}
#             );
#             marker_40096768bfa0e497a4211a2bd2ab6bf9.setIcon(icon_4eb9d56e1d61a7704e94642fce1f995f);
#
#
#         var popup_79fca6d78158fafedfc914e46e0815bd = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_2339853b6758cea1b842d8288a15760b = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAqTm9tOiBUZW1wbGUgS2FsaSBLYW1wYWw8YnI+KkNhdGVnb3JpZTogUmVsaWdpb3VzU2l0ZQ==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_79fca6d78158fafedfc914e46e0815bd.setContent(i_frame_2339853b6758cea1b842d8288a15760b);
#
#
#         marker_40096768bfa0e497a4211a2bd2ab6bf9.bindPopup(popup_79fca6d78158fafedfc914e46e0815bd)
#         ;
#
#
#
#
#             var marker_b16a6ed7c75991990680195fc8cb4f97 = L.marker(
#                 [-20.877163, 55.448789],
#                 {}
#             ).addTo(feature_group_84b247d9dba4f7d1ff3a88435874198f);
#
#
#             var icon_823e89759f7cebc8d182f7b50c6c49fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;&quot;}
#             );
#             marker_b16a6ed7c75991990680195fc8cb4f97.setIcon(icon_823e89759f7cebc8d182f7b50c6c49fd);
#
#
#         var popup_d0e8b1389e9dd14be8b41e94a1d5cef4 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_8904a73cafcb5f7c02fd3861b267146e = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAqTm9tOiBDYXRow6lkcmFsZSBTYWludC1EZW5pczxicj4qQ2F0ZWdvcmllOiBSZWxpZ2lvdXNTaXRl&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_d0e8b1389e9dd14be8b41e94a1d5cef4.setContent(i_frame_8904a73cafcb5f7c02fd3861b267146e);
#
#
#         marker_b16a6ed7c75991990680195fc8cb4f97.bindPopup(popup_d0e8b1389e9dd14be8b41e94a1d5cef4)
#         ;
#
#
#
#
#             var marker_cb5217619e246745634f5f9ef3dea592 = L.marker(
#                 [-20.879185, 55.452474],
#                 {}
#             ).addTo(feature_group_84b247d9dba4f7d1ff3a88435874198f);
#
#
#             var icon_2983fda05fd64af69bd0114902aa6609 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;&quot;}
#             );
#             marker_cb5217619e246745634f5f9ef3dea592.setIcon(icon_2983fda05fd64af69bd0114902aa6609);
#
#
#         var popup_e956e8d649dbe99ec3d30edb424bda58 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var i_frame_65d26b2e364b28f85646aa1348312b37 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&

# %%
# %%sql
# result << SELECT prc.Nom_du_POI, prc.commune, cr.code_postal, prc.Latitude "POI_Lat", prc.Longitude "POI_Long", pa.category_median
# FROM poi_reunion_clean prc, poi_activity pa, city_repository cr
# WHERE ID = URI_ID_POI
# AND prc.code_postal = cr.code_postal
# AND category_median IN
# (
#   SELECT activity_name
# FROM activity_hierarchy
# WHERE activity_to =
# (SELECT activity_id
# FROM activity_hierarchy
# WHERE activity_name = 'CulturalSite')
# )
# ORDER BY 3
# LIMIT 5;
# Out:
#  * sqlite:///Itineraires.db
# [('Temple Kali Kampal', 'Saint-Denis', 97400, -20.880661, 55.458077, 'ReligiousSite'),
#  ('Temple Kali Kampal', 'Saint-Denis', 97400, -20.880661, 55.458077, 'ReligiousSite'),
#  ('Temple Kali Kampal', 'Saint-Denis', 97400, -20.880661, 55.458077, 'ReligiousSite'),
#  ('Temple Kali Kampal', 'Saint-Denis', 97400, -20.880661, 55.458077, 'ReligiousSite'),
#  ('Temple Kali Kampal', 'Saint-Denis', 97400, -20.880661, 55.458077, 'ReligiousSite')]

# %%
result.csv('/content/drive/MyDrive/CSV4DB/result.csv')

# %%
result = pd.read_csv('/content/drive/MyDrive/CSV4DB/result.csv')

# %%
gdf = gdp.GeoDataFrame(
    activity_CulturalSite_csv, geometry=gdp.points_from_xy(activity_CulturalSite_csv.POI_Long, activity_CulturalSite_csv.POI_Lat))

# %%
gdf.head()
# Out:
#                  Nom_du_POI       commune  code_postal    POI_Lat   POI_Long  \
# 0        Temple Kali Kampal   Saint-Denis        97400 -20.880661  55.458077
# 1    Cathédrale Saint-Denis   Saint-Denis        97400 -20.877163  55.448789
# 2      Mosquée Noor-e-Islam   Saint-Denis        97400 -20.879185  55.452474
# 3         Saga du Rhum (La)  Saint-Pierre        97410 -21.312109  55.465557
# 4  Rhums et Punchs Isautier  Saint-Pierre        97410 -21.320276  55.474025
#
#           category_1                    geometry
# 0      ReligiousSite  POINT (55.45808 -20.88066)
# 1      ReligiousSite  POINT (55.44879 -20.87716)
# 2      ReligiousSite  POINT (55.45247 -20.87918)
# 3  TechnicalHeritage  POINT (55.46556 -21.31211)
# 4  TechnicalHeritage  POINT (55.47402 -21.32028)

# %%
fig, ax = plt.subplots(figsize = (10,10))
dep[dep.nuts3 == 'FR940'].plot(ax=ax,color='white', edgecolor='black')
gdf.plot(ax=ax,column="category_1", legend=True)
ax.set_title('Ile de La Réunion')
# Out:
# Text(0.5, 1.0, 'Ile de La Réunion')

# %%
# %%sql
# SELECT *
# FROM city_repository
# LIMIT 10;
# Out:
#  * sqlite:///Itineraires.db
# [(1, 'ST DENIS', 97490, 'BOIS DE NEFLES ST DENIS', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (2, 'ST DENIS', 97490, 'ST DENIS CHAUDRON', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (3, 'ST DENIS', 97490, 'LA BRETAGNE', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (4, 'ST DENIS', 97490, 'MOUFIA', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (5, 'ST DENIS', 97490, 'STE CLOTILDE', -20.933029099, 55.446977555, '2023-03-06 10:03:25'),
#  (6, 'ST JOSEPH', 97480, 'LES LIANES', -21.306243323, 55.641977434, '2023-03-06 10:03:25'),
#  (7, 'ST JOSEPH', 97480, 'VINCENDO', -21.306243323, 55.641977434, '2023-03-06 10:03:25'),
#  (8, 'ST JOSEPH', 97480, None, -21.306243323, 55.641977434, '2023-03-06 10:03:25'),
#  (9, 'ST JOSEPH', 97480, 'JEAN PETIT', -21.306243323, 55.641977434, '2023-03-06 10:03:25'),
#  (10, 'ST BENOIT', 97470, None, -21.091842698, 55.649276452, '2023-03-06 10:03:25')]

# %%
# %%sql
# SELECT Nom_du_POI, Adresse_postale, commune, Description, category_0, category_1, category_2
# FROM poi_reunion_activity
# WHERE category_1 ='LeisureSportActivityProvider'
# LIMIT 5;
# Out:
#  * sqlite:///Itineraires.db
# [('Neptune (Le)', '117, boulevard Hubert Delisle', 'Saint-Pierre', None, 'ActivityProvider', 'LeisureSportActivityProvider', None),
#  ('Zen (Le)', '2, rue Doret', 'Saint-Denis', None, 'ActivityProvider', 'LeisureSportActivityProvider', None),
#  ('Varangue (La)', '14, rue du Stade - Montgaillard', 'Saint-Denis', None, 'ActivityProvider', 'LeisureSportActivityProvider', None),
#  ('Casino du Sud', '42, boulevard Hubert Delisle', 'Saint-Pierre', None, 'ActivityProvider', 'LeisureSportActivityProvider', None),
#  ('Théâtre Vladimir Canter', '15 avenue René Cassin - Campus Universitaire du Moufia', 'Saint-Denis', None, 'ActivityProvider', 'LeisureSportActivityProvider', None)]

# %%
# %%sql
# SELECT commune, count(commune) as nb_poi
# FROM poi_reunion_clean
# GROUP BY commune
# ORDER BY nb_poi DESC
# LIMIT 10;
# Out:
#  * sqlite:///Itineraires.db
# [('Saint-Paul', 407),
#  ('Saint-Denis', 326),
#  ('Saint-Pierre', 305),
#  ('Saint-Leu', 112),
#  ('Saint-André', 79),
#  ('Le Tampon', 69),
#  ('Le Port', 63),
#  ('Saint-Benoît', 56),
#  ('Sainte-Marie', 51),
#  ('Cilaos', 51)]

# %%
# %%sql
# SELECT * FROM (
# SELECT Nom_du_POI, Adresse_postale, "Activité1"
# FROM poi_reunion_2
# WHERE commune = 'Saint-Denis'
# LIMIT 2)
# UNION
# SELECT * FROM (
# SELECT Nom_du_POI, Adresse_postale, "Activité2"
# FROM poi_reunion_activity
# where commune = 'Saint-Denis'
# limit 2)
# UNION
# SELECT * FROM (
# SELECT Nom_du_POI, Adresse_postale, "Restaurant"
# FROM poi_reunion_food
# where commune = 'Saint-Denis'
# limit 2)
# ORDER BY 3;
# Out:
#  * sqlite:///Itineraires.db
# [("Jardin de la Maison d'Edith (Le)", '59, chemin Commins', 'Activité1'),
#  ('Musée Léon Dierx', '28, rue de Paris', 'Activité1'),
#  ('Varangue (La)', '14, rue du Stade - Montgaillard', 'Activité2'),
#  ('Zen (Le)', '2, rue Doret', 'Activité2'),
#  ('Concorde (Le)', '91 bis, allée des Topazes - Bellepierre', 'Restaurant'),
#  ("Oasis (L')", '2, rue Doret', 'Restaurant')]
